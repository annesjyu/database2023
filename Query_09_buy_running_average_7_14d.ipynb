# %%
import pandas as pd

data = pd.read_csv('daily_prices_rolling_average.csv')
data
# Out:
#                trade_date  close_price  running_avg_7d  running_avg_14d
# 0     2020-07-17 00:00:00    75.390358       75.390358        75.390358
# 1     2020-07-20 00:00:00    77.725868       76.558113        76.558113
# 2     2020-07-21 00:00:00    77.332207       76.816144        76.816144
# 3     2020-07-22 00:00:00    77.776054       77.056122        77.056122
# 4     2020-07-23 00:00:00    75.385391       76.721976        76.721976
# ...                   ...          ...             ...              ...
# 1249  2025-07-09 00:00:00   176.619995      176.858568       173.762856
# 1250  2025-07-10 00:00:00   177.619995      177.057140       174.069998
# 1251  2025-07-11 00:00:00   180.190002      177.678569       175.037855
# 1252  2025-07-14 00:00:00   181.559998      178.095712       176.207140
# 1253  2025-07-15 00:00:00   182.000000      178.448569       177.294997
#
# [1254 rows x 4 columns]

# %%
import matplotlib.pyplot as plt

# make sure trade_date is datetime
data['trade_date'] = pd.to_datetime(data['trade_date'])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')

# plot close price
ax.fill_between(data['trade_date'], data['close_price'], label="Close Price", color="gray", alpha=0.3)

# plot running 7-day average
ax.plot(data['trade_date'], data['running_avg_14d'], label="14-Day Running Avg", color='coral')

# format x-axis
ax.xaxis.set_major_locator(plt.MaxNLocator(8))  # show about 8 ticks
plt.setp(ax.get_xticklabels(), rotation=45, ha='right')

# labels & legend
ax.set_xlabel("Trade Date")
ax.set_ylabel("Price")
ax.legend()
plt.title("Close Price vs 7-Day Running Average")

plt.show()
